# %% [markdown]
# **Import libraries**

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import mean_squared_error, mean_absolute_error
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow.keras.layers import LSTM, Conv1D, Activation, Flatten, Dense, BatchNormalization, Input  
from tensorflow.keras import layers
from keras.optimizers import Adam
from keras import callbacks
import keras
from keras import Sequential
from keras.layers import Flatten, Dense 
from tensorflow.keras.models import Model

sns.set_style('whitegrid')
# Set the style to whitegrid
plt.style.use('seaborn-whitegrid')
plt.style.library['seaborn-whitegrid']
plt.style.use("seaborn-v0_8-whitegrid")

from matplotlib import rcParams
rcParams['font.weight'] = 'bold'
# Out:
# 2024-06-09 10:58:46.778997: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-09 10:58:46.779046: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-09 10:58:46.780513: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# /tmp/ipykernel_1043/3627547940.py:19: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')
# /tmp/ipykernel_1043/3627547940.py:20: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.library['seaborn-whitegrid']

# %%
# Reading data
pjme = pd.read_csv('/kaggle/input/hourly-energy-consumption/PJME_hourly.csv',index_col=[0], parse_dates=[0])

# %%
pjme.head()
# Out:
#                      PJME_MW
# Datetime
# 2002-12-31 01:00:00  26498.0
# 2002-12-31 02:00:00  25147.0
# 2002-12-31 03:00:00  24574.0
# 2002-12-31 04:00:00  24393.0
# 2002-12-31 05:00:00  24860.0

# %%
pjme.tail()
# Out:
#                      PJME_MW
# Datetime
# 2018-01-01 20:00:00  44284.0
# 2018-01-01 21:00:00  43751.0
# 2018-01-01 22:00:00  42402.0
# 2018-01-01 23:00:00  40164.0
# 2018-01-02 00:00:00  38608.0

# %%
pjme.plot(style='.', figsize=(15,5), title='PJM East  hourly power consumption data - BEFORE NORMALIZATION')
plt.show()

# %%
import sklearn
def normalize_data(df):
    scaler = sklearn.preprocessing.MinMaxScaler()
    df['PJME_MW']=scaler.fit_transform(df['PJME_MW'].values.reshape(-1,1))
    return df

pjme = normalize_data(pjme)
pjme.shape
# Out:
# (145366, 1)

# %%
pjme.plot(style='.', figsize=(15,5), title='PJM East  hourly power consumption data - AFTER NORMALIZATION' )
plt.show()

# %% [markdown]
# **splitting data**

# %%
split_date = '01-Jan-2016'
pjme_train = pjme.loc[pjme.index <= split_date].copy()
pjme_test = pjme.loc[pjme.index > split_date].copy()

# %%
# Plot train and test so you can see where we have split
pjme_test \
    .rename(columns={'PJME_MW': 'TEST SET'}) \
    .join(pjme_train.rename(columns={'PJME_MW': 'TRAINING SET'}),
          how='outer') \
    .plot(figsize=(15,5), title='PJM East', style='.')
plt.show()

# %%
def load_data(train,test, seq_len):
    X_train = []
    y_train = []
    for i in range(seq_len, len(train)):
        X_train.append(train.iloc[i-seq_len : i, 0])
        y_train.append(train.iloc[i, 0])
    
    X_test = []
    y_test = []
    for i in range(seq_len, len(test)):
        X_test.append(test.iloc[i-seq_len : i, 0])
        y_test.append(test.iloc[i, 0])
   
    
    #3 convert to numpy array
    X_train = np.array(X_train)
    y_train = np.array(y_train)
    
    X_test = np.array(X_test)
    y_test = np.array(y_test)
    
    #4 reshape data to input into RNN models
    X_train = np.reshape(X_train, (X_train.shape[0], seq_len, 1))
    
    X_test = np.reshape(X_test, (X_test.shape[0], seq_len, 1))
    
    return [X_train, y_train, X_test, y_test]

# %%
#create train, test data
seq_len = 20 

X_train, y_train, X_test, y_test = load_data(pjme_train , pjme_test , seq_len)

print('X_train.shape = ',X_train.shape)
print('y_train.shape = ', y_train.shape)
print('X_test.shape = ', X_test.shape)
print('y_test.shape = ',y_test.shape)
# Out:
# X_train.shape =  (122667, 20, 1)
# y_train.shape =  (122667,)
# X_test.shape =  (22659, 20, 1)
# y_test.shape =  (22659,)

# %% [markdown]
# # **Building Models**

# %% [markdown]
# **TCN**

# %%
# !pip install -q keras-tcn --no-dependencies
# Out:
# /opt/conda/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()

# %%
pip install keras-tcn --upgrade
# Out:
# Requirement already satisfied: keras-tcn in /opt/conda/lib/python3.10/site-packages (3.5.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from keras-tcn) (1.26.4)
# Requirement already satisfied: tensorflow in /opt/conda/lib/python3.10/site-packages (from keras-tcn) (2.15.0)
# Requirement already satisfied: tensorflow-addons in /opt/conda/lib/python3.10/site-packages (from keras-tcn) (0.23.0)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow->keras-tcn) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow->keras-tcn) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /opt/conda/lib/python3.10/site-packages (from tensorflow->keras-tcn) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow->keras-tcn) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow->keras-tcn) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow->keras-tcn) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow->keras-tcn) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow->keras-tcn) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/conda/lib/python3.10/site-packages (from tensorflow->keras-tcn) (3.3.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from tensorflow->keras-tcn) (21.3)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /opt/conda/lib/python3.10/site-packages (from tensorflow->keras-tcn) (3.20.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from tensorflow->keras-tcn) (69.0.3)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow->keras-tcn) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow->keras-tcn) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/conda/lib/python3.10/site-packages (from tensorflow->keras-tcn) (4.9.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow->keras-tcn) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow->keras-tcn) (0.35.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/conda/lib/python3.10/site-packages (from tensorflow->keras-tcn) (1.59.3)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /opt/conda/lib/python3.10/site-packages (from tensorflow->keras-tcn) (2.15.1)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow->keras-tcn) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow->keras-tcn) (2.15.0)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in /opt/conda/lib/python3.10/site-packages (from tensorflow-addons->keras-tcn) (2.13.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/conda/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow->keras-tcn) (0.42.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (2.26.1)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (3.5.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (3.0.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->tensorflow->keras-tcn) (3.1.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /opt/conda/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
from tcn import TCN

def create_tcn_model(input_shape):
    inputs = Input(shape=input_shape)
    x = TCN(nb_filters=64, kernel_size=3, dilations=[1, 2, 4, 8, 16], return_sequences=False)(inputs)
    x = Dense(1, activation='linear')(x)
    model = Model(inputs=inputs, outputs=x)
    return model

# %%
input_shape = (20, 1)  # 20 time steps with 1 feature

model = create_tcn_model(input_shape)

# %%
# Set the learning rate
learning_rate = 0.001

# Compile the model with the Adam optimizer and the specified learning rate
optimizer = Adam(learning_rate=learning_rate)
model.compile(loss='mse', optimizer=optimizer)

# Earlly Stopping
callback = callbacks.EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)
checkpointer = callbacks.ModelCheckpoint(filepath="./checkpoint-{epoch:02d}.keras", verbose=1,
                                         save_best_only=True, monitor='val_loss',mode='min')

# %%
# Train the model
history = model.fit(X_train, y_train, epochs=100, batch_size=32 ,validation_split = 0.1, callbacks=[callback , checkpointer])
# Out:
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1717930779.068851    1093 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 3443/3450 [============================>.] - ETA: 0s - loss: 0.0101
# Epoch 1: val_loss improved from inf to 0.00119, saving model to ./checkpoint-01.keras
# 3450/3450 [==============================] - 29s 7ms/step - loss: 0.0101 - val_loss: 0.0012
# Epoch 2/100
# 3446/3450 [============================>.] - ETA: 0s - loss: 7.1105e-04
# Epoch 2: val_loss improved from 0.00119 to 0.00069, saving model to ./checkpoint-02.keras
# 3450/3450 [==============================] - 23s 7ms/step - loss: 7.1097e-04 - val_loss: 6.8928e-04
# Epoch 3/100
# 3442/3450 [============================>.] - ETA: 0s - loss: 4.5569e-04
# Epoch 3: val_loss improved from 0.00069 to 0.00030, saving model to ./checkpoint-03.keras
# 3450/3450 [==============================] - 23s 7ms/step - loss: 4.5537e-04 - val_loss: 3.0467e-04
# Epoch 4/100
# 3447/3450 [============================>.] - ETA: 0s - loss: 3.1767e-04
# Epoch 4: val_loss improved from 0.00030 to 0.00026, saving model to ./checkpoint-04.keras
# 3450/3450 [==============================] - 23s 7ms/step - loss: 3.1752e-04 - val_loss: 2.6249e-04
# Epoch 5/100
# 3442/3450 [============================>.] - ETA: 0s - loss: 2.7944e-04
# Epoch 5: val_loss did not improve from 0.00026
# 3450/3450 [==============================] - 22s 6ms/step - loss: 2.7930e-04 - val_loss: 3.0349e-04
# Epoch 6/100
# 3445/3450 [============================>.] - ETA: 0s - loss: 2.3666e-04
# Epoch 6: val_loss did not improve from 0.00026
# 3450/3450 [==============================] - 22s 6ms/step - loss: 2.3662e-04 - val_loss: 2.9459e-04
# Epoch 7/100
# 3445/3450 [============================>.] - ETA: 0s - loss: 2.1697e-04
# Epoch 7: val_loss improved from 0.00026 to 0.00023, saving model to ./checkpoint-07.keras
# 3450/3450 [==============================] - 22s 6ms/step - loss: 2.1704e-04 - val_loss: 2.3188e-04
# Epoch 8/100
# 3443/3450 [============================>.] - ETA: 0s - loss: 2.0111e-04
# Epoch 8: val_loss improved from 0.00023 to 0.00021, saving model to ./checkpoint-08.keras
# 3450/3450 [==============================] - 22s 6ms/step - loss: 2.0143e-04 - val_loss: 2.0945e-04
# Epoch 9/100
# 3446/3450 [============================>.] - ETA: 0s - loss: 1.9108e-04
# Epoch 9: val_loss did not improve from 0.00021
# 3450/3450 [==============================] - 22s 6ms/step - loss: 1.9104e-04 - val_loss: 2.5255e-04
# Epoch 10/100
# 3447/3450 [============================>.] - ETA: 0s - loss: 1.8106e-04
# Epoch 10: val_loss improved from 0.00021 to 0.00020, saving model to ./checkpoint-10.keras
# 3450/3450 [==============================] - 22s 6ms/step - loss: 1.8116e-04 - val_loss: 1.9799e-04
# Epoch 11/100
# 3446/3450 [============================>.] - ETA: 0s - loss: 1.7249e-04
# Epoch 11: val_loss did not improve from 0.00020
# 3450/3450 [==============================] - 22s 6ms/step - loss: 1.7240e-04 - val_loss: 2.0757e-04
# Epoch 12/100
# 3447/3450 [============================>.] - ETA: 0s - loss: 1.6855e-04
# Epoch 12: val_loss did not improve from 0.00020
# 3450/3450 [==============================] - 22s 6ms/step - loss: 1.6846e-04 - val_loss: 2.1474e-04
# Epoch 13/100
# 3448/3450 [============================>.] - ETA: 0s - loss: 1.6203e-04
# Epoch 13: val_loss did not improve from 0.00020
# 3450/3450 [==============================] - 22s 6ms/step - loss: 1.6208e-04 - val_loss: 2.2514e-04
# Epoch 14/100
# 3446/3450 [============================>.] - ETA: 0s - loss: 1.5749e-04
# Epoch 14: val_loss improved from 0.00020 to 0.00019, saving model to ./checkpoint-14.keras
# 3450/3450 [==============================] - 22s 6ms/step - loss: 1.5737e-04 - val_loss: 1.8903e-04
# Epoch 15/100
# 3447/3450 [============================>.] - ETA: 0s - loss: 1.5337e-04
# Epoch 15: val_loss did not improve from 0.00019
# 3450/3450 [==============================] - 22s 6ms/step - loss: 1.5360e-04 - val_loss: 1.9396e-04
# Epoch 16/100
# 3443/3450 [============================>.] - ETA: 0s - loss: 1.5110e-04
# Epoch 16: val_loss did not improve from 0.00019
# 3450/3450 [==============================] - 22s 6ms/step - loss: 1.5097e-04 - val_loss: 1.9013e-04
# Epoch 17/100
# 3445/3450 [============================>.] - ETA: 0s - loss: 1.4575e-04
# Epoch 17: val_loss improved from 0.00019 to 0.00018, saving model to ./checkpoint-17.keras
# 3450/3450 [==============================] - 22s 6ms/step - loss: 1.4563e-04 - val_loss: 1.7800e-04
# Epoch 18/100
# 3444/3450 [============================>.] - ETA: 0s - loss: 1.4398e-04
# Epoch 18: val_loss did not improve from 0.00018
# 3450/3450 [==============================] - 22s 6ms/step - loss: 1.4442e-04 - val_loss: 1.8288e-04
# Epoch 19/100
# 3449/3450 [============================>.] - ETA: 0s - loss: 1.4171e-04
# Epoch 19: val_loss did not improve from 0.00018
# 3450/3450 [==============================] - 22s 6ms/step - loss: 1.4169e-04 - val_loss: 1.9142e-04
# Epoch 20/100
# 3443/3450 [============================>.] - ETA: 0s - loss: 1.3769e-04
# Epoch 20: val_loss did not improve from 0.00018
# 3450/3450 [==============================] - 22s 6ms/step - loss: 1.3772e-04 - val_loss: 2.1231e-04
# Epoch 21/100
# 3447/3450 [============================>.] - ETA: 0s - loss: 1.3643e-04
# Epoch 21: val_loss did not improve from 0.00018
# 3450/3450 [==============================] - 22s 6ms/step - loss: 1.3638e-04 - val_loss: 1.8862e-04
# Epoch 22/100
# 3447/3450 [============================>.] - ETA: 0s - loss: 1.3559e-04
# Epoch 22: val_loss did not improve from 0.00018
# 3450/3450 [==============================] - 22s 6ms/step - loss: 1.3551e-04 - val_loss: 2.0495e-04
# Epoch 23/100
# 3449/3450 [============================>.] - ETA: 0s - loss: 1.3336e-04
# Epoch 23: val_loss did not improve from 0.00018
# 3450/3450 [==============================] - 22s 6ms/step - loss: 1.3339e-04 - val_loss: 1.8094e-04
# Epoch 24/100
# 3447/3450 [============================>.] - ETA: 0s - loss: 1.3139e-04
# Epoch 24: val_loss improved from 0.00018 to 0.00018, saving model to ./checkpoint-24.keras
# 3450/3450 [==============================] - 22s 6ms/step - loss: 1.3142e-04 - val_loss: 1.7599e-04
# Epoch 25/100
# 3442/3450 [============================>.] - ETA: 0s - loss: 1.2905e-04
# Epoch 25: val_loss improved from 0.00018 to 0.00016, saving model to ./checkpoint-25.keras
# 3450/3450 [==============================] - 22s 6ms/step - loss: 1.2930e-04 - val_loss: 1.6456e-04
# Epoch 26/100
# 3442/3450 [============================>.] - ETA: 0s - loss: 1.2629e-04
# Epoch 26: val_loss improved from 0.00016 to 0.00016, saving model to ./checkpoint-26.keras
# 3450/3450 [==============================] - 22s 6ms/step - loss: 1.2647e-04 - val_loss: 1.6332e-04
# Epoch 27/100
# 3444/3450 [============================>.] - ETA: 0s - loss: 1.2509e-04
# Epoch 27: val_loss improved from 0.00016 to 0.00016, saving model to ./checkpoint-27.keras
# 3450/3450 [==============================] - 22s 6ms/step - loss: 1.2506e-04 - val_loss: 1.5740e-04
# Epoch 28/100
# 3442/3450 [============================>.] - ETA: 0s - loss: 1.2427e-04
# Epoch 28: val_loss did not improve from 0.00016
# 3450/3450 [==============================] - 22s 6ms/step - loss: 1.2409e-04 - val_loss: 1.7529e-04
# Epoch 29/100
# 3446/3450 [============================>.] - ETA: 0s - loss: 1.2330e-04
# Epoch 29: val_loss improved from 0.00016 to 0.00016, saving model to ./checkpoint-29.keras
# 3450/3450 [==============================] - 22s 6ms/step - loss: 1.2330e-04 - val_loss: 1.5712e-04
# Epoch 30/100
# 3448/3450 [============================>.] - ETA: 0s - loss: 1.2104e-04
# Epoch 30: val_loss did not improve from 0.00016
# 3450/3450 [==============================] - 22s 6ms/step - loss: 1.2104e-04 - val_loss: 1.7170e-04
# Epoch 31/100
# 3446/3450 [============================>.] - ETA: 0s - loss: 1.2047e-04
# Epoch 31: val_loss did not improve from 0.00016
# 3450/3450 [==============================] - 22s 6ms/step - loss: 1.2059e-04 - val_loss: 1.7249e-04
# Epoch 32/100
# 3444/3450 [============================>.] - ETA: 0s - loss: 1.1762e-04
# Epoch 32: val_loss did not improve from 0.00016
# 3450/3450 [==============================] - 22s 6ms/step - loss: 1.1752e-04 - val_loss: 1.6359e-04
# Epoch 33/100
# 3443/3450 [============================>.] - ETA: 0s - loss: 1.1684e-04
# Epoch 33: val_loss did not improve from 0.00016
# 3450/3450 [==============================] - 22s 6ms/step - loss: 1.1685e-04 - val_loss: 1.5717e-04
# Epoch 34/100
# 3450/3450 [==============================] - ETA: 0s - loss: 1.1680e-04
# Epoch 34: val_loss did not improve from 0.00016
# 3450/3450 [==============================] - 22s 6ms/step - loss: 1.1680e-04 - val_loss: 1.6507e-04
# Epoch 35/100
# 3445/3450 [============================>.] - ETA: 0s - loss: 1.1623e-04
# Epoch 35: val_loss did not improve from 0.00016
# 3450/3450 [==============================] - 22s 6ms/step - loss: 1.1622e-04 - val_loss: 1.6632e-04
# Epoch 36/100
# 3443/3450 [============================>.] - ETA: 0s - loss: 1.1544e-04
# Epoch 36: val_loss did not improve from 0.00016
# 3450/3450 [==============================] - 22s 6ms/step - loss: 1.1546e-04 - val_loss: 1.6982e-04
# Epoch 37/100
# 3445/3450 [============================>.] - ETA: 0s - loss: 1.1362e-04
# Epoch 37: val_loss improved from 0.00016 to 0.00015, saving model to ./checkpoint-37.keras
# 3450/3450 [==============================] - 22s 6ms/step - loss: 1.1353e-04 - val_loss: 1.5067e-04
# Epoch 38/100
# 3450/3450 [==============================] - ETA: 0s - loss: 1.1320e-04
# Epoch 38: val_loss did not improve from 0.00015
# 3450/3450 [==============================] - 22s 6ms/step - loss: 1.1320e-04 - val_loss: 1.5379e-04
# Epoch 39/100
# 3445/3450 [============================>.] - ETA: 0s - loss: 1.1205e-04
# Epoch 39: val_loss did not improve from 0.00015
# 3450/3450 [==============================] - 22s 6ms/step - loss: 1.1198e-04 - val_loss: 1.5195e-04
# Epoch 40/100
# 3442/3450 [============================>.] - ETA: 0s - loss: 1.1108e-04
# Epoch 40: val_loss did not improve from 0.00015
# 3450/3450 [==============================] - 22s 6ms/step - loss: 1.1100e-04 - val_loss: 1.5716e-04
# Epoch 41/100
# 3446/3450 [============================>.] - ETA: 0s - loss: 1.1042e-04
# Epoch 41: val_loss did not improve from 0.00015
# 3450/3450 [==============================] - 22s 6ms/step - loss: 1.1074e-04 - val_loss: 1.6934e-04
# Epoch 42/100
# 3449/3450 [============================>.] - ETA: 0s - loss: 1.1065e-04
# Epoch 42: val_loss did not improve from 0.00015
# 3450/3450 [==============================] - 22s 6ms/step - loss: 1.1064e-04 - val_loss: 1.6312e-04
# Epoch 43/100
# 3446/3450 [============================>.] - ETA: 0s - loss: 1.1196e-04
# Epoch 43: val_loss improved from 0.00015 to 0.00015, saving model to ./checkpoint-43.keras
# 3450/3450 [==============================] - 22s 6ms/step - loss: 1.1187e-04 - val_loss: 1.4753e-04
# Epoch 44/100
# 3447/3450 [============================>.] - ETA: 0s - loss: 1.1223e-04
# Epoch 44: val_loss did not improve from 0.00015
# 3450/3450 [==============================] - 22s 6ms/step - loss: 1.1223e-04 - val_loss: 1.6254e-04
# Epoch 45/100
# 3445/3450 [============================>.] - ETA: 0s - loss: 1.0947e-04
# Epoch 45: val_loss did not improve from 0.00015
# 3450/3450 [==============================] - 22s 6ms/step - loss: 1.0967e-04 - val_loss: 1.4779e-04
# Epoch 46/100
# 3443/3450 [============================>.] - ETA: 0s - loss: 1.0871e-04
# Epoch 46: val_loss did not improve from 0.00015
# 3450/3450 [==============================] - 22s 6ms/step - loss: 1.0885e-04 - val_loss: 1.5309e-04
# Epoch 47/100
# 3442/3450 [============================>.] - ETA: 0s - loss: 1.0852e-04
# Epoch 47: val_loss did not improve from 0.00015
# 3450/3450 [==============================] - 22s 6ms/step - loss: 1.0862e-04 - val_loss: 1.5284e-04
# Epoch 48/100
# 3447/3450 [============================>.] - ETA: 0s - loss: 1.0766e-04
# Epoch 48: val_loss did not improve from 0.00015
# 3450/3450 [==============================] - 22s 6ms/step - loss: 1.0769e-04 - val_loss: 1.6846e-04
# Epoch 49/100
# 3444/3450 [============================>.] - ETA: 0s - loss: 1.0706e-04
# Epoch 49: val_loss did not improve from 0.00015
# 3450/3450 [==============================] - 22s 6ms/step - loss: 1.0696e-04 - val_loss: 1.7071e-04
# Epoch 50/100
# 3448/3450 [============================>.] - ETA: 0s - loss: 1.0638e-04
# Epoch 50: val_loss did not improve from 0.00015
# 3450/3450 [==============================] - 22s 6ms/step - loss: 1.0638e-04 - val_loss: 1.6423e-04
# Epoch 51/100
# 3447/3450 [============================>.] - ETA: 0s - loss: 1.0671e-04
# Epoch 51: val_loss did not improve from 0.00015
# 3450/3450 [==============================] - 22s 6ms/step - loss: 1.0670e-04 - val_loss: 1.5201e-04
# Epoch 52/100
# 3442/3450 [============================>.] - ETA: 0s - loss: 1.0589e-04
# Epoch 52: val_loss improved from 0.00015 to 0.00015, saving model to ./checkpoint-52.keras
# 3450/3450 [==============================] - 22s 6ms/step - loss: 1.0610e-04 - val_loss: 1.4518e-04
# Epoch 53/100
# 3445/3450 [============================>.] - ETA: 0s - loss: 1.0533e-04
# Epoch 53: val_loss did not improve from 0.00015
# 3450/3450 [==============================] - 22s 6ms/step - loss: 1.0530e-04 - val_loss: 1.8605e-04
# Epoch 54/100
# 3445/3450 [============================>.] - ETA: 0s - loss: 1.0431e-04
# Epoch 54: val_loss improved from 0.00015 to 0.00013, saving model to ./checkpoint-54.keras
# 3450/3450 [==============================] - 22s 6ms/step - loss: 1.0432e-04 - val_loss: 1.3257e-04
# Epoch 55/100
# 3443/3450 [============================>.] - ETA: 0s - loss: 1.0298e-04
# Epoch 55: val_loss did not improve from 0.00013
# 3450/3450 [==============================] - 22s 6ms/step - loss: 1.0304e-04 - val_loss: 1.3932e-04
# Epoch 56/100
# 3442/3450 [============================>.] - ETA: 0s - loss: 1.0686e-04
# Epoch 56: val_loss did not improve from 0.00013
# 3450/3450 [==============================] - 22s 6ms/step - loss: 1.0686e-04 - val_loss: 1.6254e-04
# Epoch 57/100
# 3450/3450 [==============================] - ETA: 0s - loss: 1.0480e-04
# Epoch 57: val_loss did not improve from 0.00013
# 3450/3450 [==============================] - 22s 6ms/step - loss: 1.0480e-04 - val_loss: 1.3827e-04
# Epoch 58/100
# 3450/3450 [==============================] - ETA: 0s - loss: 1.0441e-04
# Epoch 58: val_loss did not improve from 0.00013
# 3450/3450 [==============================] - 22s 6ms/step - loss: 1.0441e-04 - val_loss: 1.4037e-04
# Epoch 59/100
# 3447/3450 [============================>.] - ETA: 0s - loss: 1.0227e-04
# Epoch 59: val_loss did not improve from 0.00013
# 3450/3450 [==============================] - 22s 6ms/step - loss: 1.0253e-04 - val_loss: 1.7430e-04
# Epoch 60/100
# 3444/3450 [============================>.] - ETA: 0s - loss: 1.0394e-04
# Epoch 60: val_loss did not improve from 0.00013
# 3450/3450 [==============================] - 22s 6ms/step - loss: 1.0395e-04 - val_loss: 1.4347e-04
# Epoch 61/100
# 3445/3450 [============================>.] - ETA: 0s - loss: 1.0265e-04
# Epoch 61: val_loss did not improve from 0.00013
# 3450/3450 [==============================] - 22s 6ms/step - loss: 1.0258e-04 - val_loss: 1.4302e-04
# Epoch 62/100
# 3450/3450 [==============================] - ETA: 0s - loss: 1.0227e-04
# Epoch 62: val_loss did not improve from 0.00013
# 3450/3450 [==============================] - 22s 6ms/step - loss: 1.0227e-04 - val_loss: 1.5567e-04
# Epoch 63/100
# 3448/3450 [============================>.] - ETA: 0s - loss: 1.0648e-04
# Epoch 63: val_loss did not improve from 0.00013
# 3450/3450 [==============================] - 22s 6ms/step - loss: 1.0645e-04 - val_loss: 1.7765e-04
# Epoch 64/100
# 3445/3450 [============================>.] - ETA: 0s - loss: 1.0249e-04
# Epoch 64: val_loss did not improve from 0.00013
# 3450/3450 [==============================] - 22s 6ms/step - loss: 1.0244e-04 - val_loss: 1.3395e-04
# Epoch 64: early stopping

# %% [markdown]
# **Models Evaluation**

# %%
# plot history
plt.plot(history.history['loss'],'r-o', label='train')
plt.plot(history.history['val_loss'],'b-o', label='val')
plt.legend()
plt.title("TCN MSE" , weight='bold')
plt.show()

# %%
# make a prediction
yhat_train = model.predict(X_train)
# Out:
# 3834/3834 [==============================] - 10s 3ms/step

# %%
import sklearn.metrics as skm
from math import sqrt

def model_metrics(target: pd.DataFrame, predictions: []) -> None:
    print("Explained variance regression score: %.3f" %skm.explained_variance_score(target, predictions))
    print("Maximum residual error: %.3f" %skm.max_error(target, predictions))
    print("Mean squared error: %.3f" %skm.mean_squared_error(target, predictions))
    print("R2 Score: %.3f" %skm.r2_score(target, predictions))
    print("Root-mean-square Error: %.3f" %sqrt(skm.mean_squared_error(target, predictions)))
    print("Median_absolute_error: %.3f" %skm.median_absolute_error(target , predictions))
    print("Mean_absolute_error: %.3f" %skm.mean_absolute_error(target , predictions))

# %%
# Test Set 
yhat = model.predict(X_test)
# Out:
# 709/709 [==============================] - 2s 3ms/step

# %%
print("***  TCN Evaluation ***** ")
model_metrics(y_test , yhat)
# Out:
# ***  TCN Evaluation *****
# Explained variance regression score: 0.992
# Maximum residual error: 0.227
# Mean squared error: 0.000
# R2 Score: 0.991
# Root-mean-square Error: 0.012
# Median_absolute_error: 0.004
# Mean_absolute_error: 0.006

# %%
plt.figure(figsize=(15,6))
plt.plot( y_test[:1000], marker='.', label="actual")
plt.plot( yhat[:1000], 'r', label="prediction")

plt.tight_layout()
sns.despine(top=True)
plt.subplots_adjust(left=0.07)
plt.ylabel('PJME_MW', size=15 , weight='bold')
plt.xlabel('Time step', size=15 , weight='bold')
plt.legend(fontsize=15)
plt.title("TCN PJME_MW Prediction" , weight='bold')
plt.show();
