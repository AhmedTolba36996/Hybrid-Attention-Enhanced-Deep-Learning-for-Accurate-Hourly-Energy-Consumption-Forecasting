# %% [markdown]
# **Import libraries**

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import mean_squared_error, mean_absolute_error
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow.keras.layers import LSTM, Conv1D, Activation, Flatten, Dense, BatchNormalization, Input
from tensorflow.keras import layers
from keras.optimizers import Adam
from keras import callbacks
import keras

sns.set_style('whitegrid')
# Set the style to whitegrid
plt.style.use('seaborn-whitegrid')
plt.style.library['seaborn-whitegrid']
plt.style.use("seaborn-v0_8-whitegrid")

from matplotlib import rcParams
rcParams['font.weight'] = 'bold'
# Out:
# 2024-06-09 09:47:04.934404: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-09 09:47:04.934529: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-09 09:47:05.070367: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# /tmp/ipykernel_24/2605061694.py:16: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')
# /tmp/ipykernel_24/2605061694.py:17: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.library['seaborn-whitegrid']

# %%
# Reading data
pjme = pd.read_csv('/kaggle/input/hourly-energy-consumption/PJME_hourly.csv',index_col=[0], parse_dates=[0])

# %%
pjme.head()
# Out:
#                      PJME_MW
# Datetime
# 2002-12-31 01:00:00  26498.0
# 2002-12-31 02:00:00  25147.0
# 2002-12-31 03:00:00  24574.0
# 2002-12-31 04:00:00  24393.0
# 2002-12-31 05:00:00  24860.0

# %%
pjme.tail()
# Out:
#                      PJME_MW
# Datetime
# 2018-01-01 20:00:00  44284.0
# 2018-01-01 21:00:00  43751.0
# 2018-01-01 22:00:00  42402.0
# 2018-01-01 23:00:00  40164.0
# 2018-01-02 00:00:00  38608.0

# %%
pjme.plot(style='.', figsize=(15,5), title='PJM East  hourly power consumption data - BEFORE NORMALIZATION')
plt.show()

# %%
import sklearn
def normalize_data(df):
    scaler = sklearn.preprocessing.MinMaxScaler()
    df['PJME_MW']=scaler.fit_transform(df['PJME_MW'].values.reshape(-1,1))
    return df

pjme = normalize_data(pjme)
pjme.shape
# Out:
# (145366, 1)

# %%
pjme.plot(style='.', figsize=(15,5), title='PJM East  hourly power consumption data - AFTER NORMALIZATION' )
plt.show()

# %% [markdown]
# **splitting data**

# %%
split_date = '01-Jan-2016'
pjme_train = pjme.loc[pjme.index <= split_date].copy()
pjme_test = pjme.loc[pjme.index > split_date].copy()

# %%
# Plot train and test so you can see where we have split
pjme_test \
    .rename(columns={'PJME_MW': 'TEST SET'}) \
    .join(pjme_train.rename(columns={'PJME_MW': 'TRAINING SET'}),
          how='outer') \
    .plot(figsize=(15,5), title='PJM East', style='.')
plt.show()

# %%
def load_data(train,test, seq_len):
    X_train = []
    y_train = []
    for i in range(seq_len, len(train)):
        X_train.append(train.iloc[i-seq_len : i, 0])
        y_train.append(train.iloc[i, 0])
    
    X_test = []
    y_test = []
    for i in range(seq_len, len(test)):
        X_test.append(test.iloc[i-seq_len : i, 0])
        y_test.append(test.iloc[i, 0])
   
    
    #3 convert to numpy array
    X_train = np.array(X_train)
    y_train = np.array(y_train)
    
    X_test = np.array(X_test)
    y_test = np.array(y_test)
    
    #4 reshape data to input into RNN models
    X_train = np.reshape(X_train, (X_train.shape[0], seq_len, 1))
    
    X_test = np.reshape(X_test, (X_test.shape[0], seq_len, 1))
    
    return [X_train, y_train, X_test, y_test]

# %%
#create train, test data
seq_len = 20 

X_train, y_train, X_test, y_test = load_data(pjme_train , pjme_test , seq_len)

print('X_train.shape = ',X_train.shape)
print('y_train.shape = ', y_train.shape)
print('X_test.shape = ', X_test.shape)
print('y_test.shape = ',y_test.shape)
# Out:
# X_train.shape =  (122667, 20, 1)
# y_train.shape =  (122667,)
# X_test.shape =  (22659, 20, 1)
# y_test.shape =  (22659,)

# %% [markdown]
# # **Building Models**

# %% [markdown]
# **Attention**

# %%
class Attention(layers.Layer):
    def __init__(self, units):
        super(Attention, self).__init__()
        self.units = units

    def build(self, input_shape):
        self.W = self.add_weight(shape=(input_shape[-1], self.units),
                                 initializer='random_normal',
                                 trainable=True)
        self.b = self.add_weight(shape=(self.units,),
                                 initializer='zeros',
                                 trainable=True)
        self.V = self.add_weight(shape=(self.units,),
                                 initializer='random_normal',
                                 trainable=True)

    def call(self, inputs):
        query = tf.matmul(inputs, self.W) + self.b
        query = tf.nn.tanh(query)
        score = tf.reduce_sum(tf.multiply(query, self.V), axis=2)
        attention_weights = tf.nn.softmax(score, axis=1)
        context_vector = tf.reduce_sum(tf.multiply(inputs, tf.expand_dims(attention_weights, axis=-1)), axis=1)
        return context_vector

# %%
inputs_1 = layers.Input(shape=(X_train.shape[1], 1))
x = layers.LSTM(64, return_sequences=True)(inputs_1)
x = Attention(units=32)(x)
outputs = Dense(1, activation='linear')(x)
model = tf.keras.models.Model(inputs=inputs_1, outputs=outputs)

# %%
# Set the learning rate
learning_rate = 0.001

# Compile the model with the Adam optimizer and the specified learning rate
optimizer = Adam(learning_rate=learning_rate)
model.compile(loss='mse', optimizer=optimizer)

# Earlly Stopping
callback = callbacks.EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)
checkpointer = callbacks.ModelCheckpoint(filepath="./checkpoint-{epoch:02d}.keras", verbose=1,
                                         save_best_only=True, monitor='val_loss',mode='min')

# %%
# Train the model
history = model.fit(X_train, y_train, epochs=100, batch_size=32 ,validation_split = 0.1, callbacks=[callback , checkpointer])
# Out:
# Epoch 1/100
# 3439/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0090
# Epoch 1: val_loss improved from inf to 0.00051, saving model to ./checkpoint-01.keras
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 16s 4ms/step - loss: 0.0090 - val_loss: 5.1137e-04
# Epoch 2/100
# 3449/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4702e-04
# Epoch 2: val_loss improved from 0.00051 to 0.00041, saving model to ./checkpoint-02.keras
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 4.4700e-04 - val_loss: 4.0917e-04
# Epoch 3/100
# 3436/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7276e-04
# Epoch 3: val_loss improved from 0.00041 to 0.00041, saving model to ./checkpoint-03.keras
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 3.7274e-04 - val_loss: 4.0666e-04
# Epoch 4/100
# 3443/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4576e-04
# Epoch 4: val_loss improved from 0.00041 to 0.00039, saving model to ./checkpoint-04.keras
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 3.4575e-04 - val_loss: 3.9489e-04
# Epoch 5/100
# 3447/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1294e-04
# Epoch 5: val_loss improved from 0.00039 to 0.00030, saving model to ./checkpoint-05.keras
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 3.1293e-04 - val_loss: 3.0194e-04
# Epoch 6/100
# 3447/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7298e-04
# Epoch 6: val_loss improved from 0.00030 to 0.00029, saving model to ./checkpoint-06.keras
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 2.7298e-04 - val_loss: 2.8586e-04
# Epoch 7/100
# 3444/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5244e-04
# Epoch 7: val_loss improved from 0.00029 to 0.00026, saving model to ./checkpoint-07.keras
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 2.5244e-04 - val_loss: 2.6456e-04
# Epoch 8/100
# 3442/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3894e-04
# Epoch 8: val_loss did not improve from 0.00026
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 2.3895e-04 - val_loss: 2.7515e-04
# Epoch 9/100
# 3445/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3461e-04
# Epoch 9: val_loss did not improve from 0.00026
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - loss: 2.3460e-04 - val_loss: 2.9827e-04
# Epoch 10/100
# 3442/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3030e-04
# Epoch 10: val_loss did not improve from 0.00026
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 2.3028e-04 - val_loss: 2.8515e-04
# Epoch 11/100
# 3443/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1692e-04
# Epoch 11: val_loss improved from 0.00026 to 0.00025, saving model to ./checkpoint-11.keras
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - loss: 2.1692e-04 - val_loss: 2.4645e-04
# Epoch 12/100
# 3442/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0610e-04
# Epoch 12: val_loss improved from 0.00025 to 0.00024, saving model to ./checkpoint-12.keras
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 2.0610e-04 - val_loss: 2.3668e-04
# Epoch 13/100
# 3436/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0131e-04
# Epoch 13: val_loss did not improve from 0.00024
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 2.0131e-04 - val_loss: 2.4595e-04
# Epoch 14/100
# 3447/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0034e-04
# Epoch 14: val_loss improved from 0.00024 to 0.00022, saving model to ./checkpoint-14.keras
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 2.0034e-04 - val_loss: 2.1909e-04
# Epoch 15/100
# 3441/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8988e-04
# Epoch 15: val_loss did not improve from 0.00022
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 1.8988e-04 - val_loss: 2.2240e-04
# Epoch 16/100
# 3447/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9029e-04
# Epoch 16: val_loss improved from 0.00022 to 0.00021, saving model to ./checkpoint-16.keras
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 20s 4ms/step - loss: 1.9029e-04 - val_loss: 2.0981e-04
# Epoch 17/100
# 3449/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8426e-04
# Epoch 17: val_loss did not improve from 0.00021
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 1.8426e-04 - val_loss: 2.4328e-04
# Epoch 18/100
# 3442/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7848e-04
# Epoch 18: val_loss improved from 0.00021 to 0.00021, saving model to ./checkpoint-18.keras
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 1.7847e-04 - val_loss: 2.0510e-04
# Epoch 19/100
# 3447/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8157e-04
# Epoch 19: val_loss did not improve from 0.00021
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - loss: 1.8156e-04 - val_loss: 2.0909e-04
# Epoch 20/100
# 3445/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7815e-04
# Epoch 20: val_loss did not improve from 0.00021
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 1.7814e-04 - val_loss: 2.1799e-04
# Epoch 21/100
# 3445/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6333e-04
# Epoch 21: val_loss did not improve from 0.00021
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - loss: 1.6334e-04 - val_loss: 2.2225e-04
# Epoch 22/100
# 3435/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7295e-04
# Epoch 22: val_loss improved from 0.00021 to 0.00020, saving model to ./checkpoint-22.keras
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 1.7291e-04 - val_loss: 2.0471e-04
# Epoch 23/100
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6567e-04
# Epoch 23: val_loss improved from 0.00020 to 0.00020, saving model to ./checkpoint-23.keras
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - loss: 1.6566e-04 - val_loss: 2.0219e-04
# Epoch 24/100
# 3441/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6155e-04
# Epoch 24: val_loss improved from 0.00020 to 0.00019, saving model to ./checkpoint-24.keras
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 1.6155e-04 - val_loss: 1.9497e-04
# Epoch 25/100
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6180e-04
# Epoch 25: val_loss did not improve from 0.00019
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 1.6180e-04 - val_loss: 1.9916e-04
# Epoch 26/100
# 3439/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5299e-04
# Epoch 26: val_loss did not improve from 0.00019
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 1.5301e-04 - val_loss: 2.1483e-04
# Epoch 27/100
# 3445/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5480e-04
# Epoch 27: val_loss did not improve from 0.00019
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 1.5480e-04 - val_loss: 2.1612e-04
# Epoch 28/100
# 3444/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5345e-04
# Epoch 28: val_loss did not improve from 0.00019
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 1.5345e-04 - val_loss: 2.1932e-04
# Epoch 29/100
# 3448/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5363e-04
# Epoch 29: val_loss improved from 0.00019 to 0.00019, saving model to ./checkpoint-29.keras
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 1.5363e-04 - val_loss: 1.9362e-04
# Epoch 30/100
# 3444/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5169e-04
# Epoch 30: val_loss did not improve from 0.00019
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 1.5168e-04 - val_loss: 1.9753e-04
# Epoch 31/100
# 3447/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4128e-04
# Epoch 31: val_loss improved from 0.00019 to 0.00019, saving model to ./checkpoint-31.keras
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - loss: 1.4129e-04 - val_loss: 1.9307e-04
# Epoch 32/100
# 3436/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4488e-04
# Epoch 32: val_loss improved from 0.00019 to 0.00019, saving model to ./checkpoint-32.keras
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 1.4489e-04 - val_loss: 1.8668e-04
# Epoch 33/100
# 3440/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4916e-04
# Epoch 33: val_loss did not improve from 0.00019
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 1.4914e-04 - val_loss: 1.9145e-04
# Epoch 34/100
# 3441/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3844e-04
# Epoch 34: val_loss improved from 0.00019 to 0.00018, saving model to ./checkpoint-34.keras
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - loss: 1.3845e-04 - val_loss: 1.8465e-04
# Epoch 35/100
# 3438/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4280e-04
# Epoch 35: val_loss did not improve from 0.00018
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 1.4280e-04 - val_loss: 1.9209e-04
# Epoch 36/100
# 3443/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3470e-04
# Epoch 36: val_loss did not improve from 0.00018
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - loss: 1.3472e-04 - val_loss: 1.9338e-04
# Epoch 37/100
# 3440/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3997e-04
# Epoch 37: val_loss improved from 0.00018 to 0.00018, saving model to ./checkpoint-37.keras
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 1.3996e-04 - val_loss: 1.8104e-04
# Epoch 38/100
# 3436/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3327e-04
# Epoch 38: val_loss improved from 0.00018 to 0.00018, saving model to ./checkpoint-38.keras
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - loss: 1.3331e-04 - val_loss: 1.7982e-04
# Epoch 39/100
# 3440/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3575e-04
# Epoch 39: val_loss did not improve from 0.00018
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 1.3574e-04 - val_loss: 1.9533e-04
# Epoch 40/100
# 3448/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3240e-04
# Epoch 40: val_loss did not improve from 0.00018
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 1.3240e-04 - val_loss: 1.8563e-04
# Epoch 41/100
# 3441/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3484e-04
# Epoch 41: val_loss improved from 0.00018 to 0.00017, saving model to ./checkpoint-41.keras
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - loss: 1.3484e-04 - val_loss: 1.7000e-04
# Epoch 42/100
# 3445/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3236e-04
# Epoch 42: val_loss did not improve from 0.00017
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 1.3236e-04 - val_loss: 1.7389e-04
# Epoch 43/100
# 3439/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3509e-04
# Epoch 43: val_loss improved from 0.00017 to 0.00017, saving model to ./checkpoint-43.keras
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - loss: 1.3508e-04 - val_loss: 1.6942e-04
# Epoch 44/100
# 3443/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3009e-04
# Epoch 44: val_loss did not improve from 0.00017
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - loss: 1.3009e-04 - val_loss: 1.7897e-04
# Epoch 45/100
# 3437/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2667e-04
# Epoch 45: val_loss improved from 0.00017 to 0.00016, saving model to ./checkpoint-45.keras
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - loss: 1.2668e-04 - val_loss: 1.6412e-04
# Epoch 46/100
# 3440/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2544e-04
# Epoch 46: val_loss did not improve from 0.00016
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - loss: 1.2545e-04 - val_loss: 1.7118e-04
# Epoch 47/100
# 3439/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2627e-04
# Epoch 47: val_loss did not improve from 0.00016
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - loss: 1.2627e-04 - val_loss: 1.6948e-04
# Epoch 48/100
# 3436/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2611e-04
# Epoch 48: val_loss did not improve from 0.00016
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 1.2611e-04 - val_loss: 1.7056e-04
# Epoch 49/100
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2373e-04
# Epoch 49: val_loss improved from 0.00016 to 0.00016, saving model to ./checkpoint-49.keras
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - loss: 1.2373e-04 - val_loss: 1.5666e-04
# Epoch 50/100
# 3439/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2148e-04
# Epoch 50: val_loss did not improve from 0.00016
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 1.2149e-04 - val_loss: 1.6246e-04
# Epoch 51/100
# 3444/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2546e-04
# Epoch 51: val_loss did not improve from 0.00016
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - loss: 1.2546e-04 - val_loss: 1.5875e-04
# Epoch 52/100
# 3441/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2095e-04
# Epoch 52: val_loss did not improve from 0.00016
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 1.2095e-04 - val_loss: 1.6273e-04
# Epoch 53/100
# 3447/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1866e-04
# Epoch 53: val_loss did not improve from 0.00016
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - loss: 1.1866e-04 - val_loss: 1.7872e-04
# Epoch 54/100
# 3444/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2210e-04
# Epoch 54: val_loss did not improve from 0.00016
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 1.2209e-04 - val_loss: 1.5856e-04
# Epoch 55/100
# 3448/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1973e-04
# Epoch 55: val_loss did not improve from 0.00016
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 1.1972e-04 - val_loss: 1.5932e-04
# Epoch 56/100
# 3437/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1757e-04
# Epoch 56: val_loss did not improve from 0.00016
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - loss: 1.1757e-04 - val_loss: 1.8084e-04
# Epoch 57/100
# 3449/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1746e-04
# Epoch 57: val_loss improved from 0.00016 to 0.00016, saving model to ./checkpoint-57.keras
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 1.1746e-04 - val_loss: 1.5574e-04
# Epoch 58/100
# 3438/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1191e-04
# Epoch 58: val_loss did not improve from 0.00016
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - loss: 1.1192e-04 - val_loss: 1.6206e-04
# Epoch 59/100
# 3446/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1302e-04
# Epoch 59: val_loss did not improve from 0.00016
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - loss: 1.1303e-04 - val_loss: 1.6709e-04
# Epoch 60/100
# 3435/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1801e-04
# Epoch 60: val_loss did not improve from 0.00016
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 1.1799e-04 - val_loss: 1.6845e-04
# Epoch 61/100
# 3440/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0958e-04
# Epoch 61: val_loss improved from 0.00016 to 0.00015, saving model to ./checkpoint-61.keras
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - loss: 1.0959e-04 - val_loss: 1.5448e-04
# Epoch 62/100
# 3448/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1020e-04
# Epoch 62: val_loss did not improve from 0.00015
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 1.1020e-04 - val_loss: 1.5543e-04
# Epoch 63/100
# 3437/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0846e-04
# Epoch 63: val_loss did not improve from 0.00015
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - loss: 1.0848e-04 - val_loss: 1.5875e-04
# Epoch 64/100
# 3444/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1036e-04
# Epoch 64: val_loss improved from 0.00015 to 0.00015, saving model to ./checkpoint-64.keras
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - loss: 1.1037e-04 - val_loss: 1.5087e-04
# Epoch 65/100
# 3442/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0864e-04
# Epoch 65: val_loss did not improve from 0.00015
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 1.0865e-04 - val_loss: 1.5315e-04
# Epoch 66/100
# 3438/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1303e-04
# Epoch 66: val_loss did not improve from 0.00015
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - loss: 1.1303e-04 - val_loss: 1.5735e-04
# Epoch 67/100
# 3441/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0897e-04
# Epoch 67: val_loss did not improve from 0.00015
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 1.0897e-04 - val_loss: 1.5487e-04
# Epoch 68/100
# 3439/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1096e-04
# Epoch 68: val_loss did not improve from 0.00015
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - loss: 1.1096e-04 - val_loss: 1.6019e-04
# Epoch 69/100
# 3438/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0747e-04
# Epoch 69: val_loss did not improve from 0.00015
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - loss: 1.0748e-04 - val_loss: 1.5760e-04
# Epoch 70/100
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0943e-04
# Epoch 70: val_loss did not improve from 0.00015
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 1.0943e-04 - val_loss: 1.5402e-04
# Epoch 71/100
# 3441/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0908e-04
# Epoch 71: val_loss did not improve from 0.00015
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - loss: 1.0908e-04 - val_loss: 1.5408e-04
# Epoch 72/100
# 3436/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0605e-04
# Epoch 72: val_loss did not improve from 0.00015
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 1.0606e-04 - val_loss: 1.5315e-04
# Epoch 73/100
# 3447/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1032e-04
# Epoch 73: val_loss improved from 0.00015 to 0.00015, saving model to ./checkpoint-73.keras
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - loss: 1.1032e-04 - val_loss: 1.4737e-04
# Epoch 74/100
# 3438/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0426e-04
# Epoch 74: val_loss did not improve from 0.00015
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 1.0427e-04 - val_loss: 1.5764e-04
# Epoch 75/100
# 3437/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0557e-04
# Epoch 75: val_loss improved from 0.00015 to 0.00015, saving model to ./checkpoint-75.keras
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 1.0558e-04 - val_loss: 1.4601e-04
# Epoch 76/100
# 3446/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0760e-04
# Epoch 76: val_loss did not improve from 0.00015
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - loss: 1.0760e-04 - val_loss: 1.4906e-04
# Epoch 77/100
# 3441/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0611e-04
# Epoch 77: val_loss did not improve from 0.00015
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 1.0611e-04 - val_loss: 1.6841e-04
# Epoch 78/100
# 3441/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0564e-04
# Epoch 78: val_loss did not improve from 0.00015
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - loss: 1.0565e-04 - val_loss: 1.4768e-04
# Epoch 79/100
# 3436/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.9220e-05
# Epoch 79: val_loss did not improve from 0.00015
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - loss: 9.9242e-05 - val_loss: 1.5640e-04
# Epoch 80/100
# 3439/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0453e-04
# Epoch 80: val_loss did not improve from 0.00015
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 1.0453e-04 - val_loss: 1.5511e-04
# Epoch 81/100
# 3445/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0633e-04
# Epoch 81: val_loss did not improve from 0.00015
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - loss: 1.0633e-04 - val_loss: 1.5208e-04
# Epoch 82/100
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0894e-04
# Epoch 82: val_loss improved from 0.00015 to 0.00015, saving model to ./checkpoint-82.keras
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 1.0893e-04 - val_loss: 1.4556e-04
# Epoch 83/100
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0343e-04
# Epoch 83: val_loss did not improve from 0.00015
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - loss: 1.0343e-04 - val_loss: 1.4955e-04
# Epoch 84/100
# 3438/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0245e-04
# Epoch 84: val_loss did not improve from 0.00015
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - loss: 1.0246e-04 - val_loss: 1.5216e-04
# Epoch 85/100
# 3448/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0175e-04
# Epoch 85: val_loss improved from 0.00015 to 0.00015, saving model to ./checkpoint-85.keras
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 1.0175e-04 - val_loss: 1.4520e-04
# Epoch 86/100
# 3444/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.8062e-05
# Epoch 86: val_loss did not improve from 0.00015
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - loss: 9.8070e-05 - val_loss: 1.4848e-04
# Epoch 87/100
# 3440/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0619e-04
# Epoch 87: val_loss improved from 0.00015 to 0.00014, saving model to ./checkpoint-87.keras
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 1.0618e-04 - val_loss: 1.3696e-04
# Epoch 88/100
# 3449/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0047e-04
# Epoch 88: val_loss did not improve from 0.00014
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - loss: 1.0047e-04 - val_loss: 1.5893e-04
# Epoch 89/100
# 3437/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0278e-04
# Epoch 89: val_loss did not improve from 0.00014
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - loss: 1.0277e-04 - val_loss: 1.4912e-04
# Epoch 90/100
# 3437/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0148e-04
# Epoch 90: val_loss did not improve from 0.00014
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 1.0148e-04 - val_loss: 1.4372e-04
# Epoch 91/100
# 3449/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0338e-04
# Epoch 91: val_loss did not improve from 0.00014
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - loss: 1.0337e-04 - val_loss: 1.4983e-04
# Epoch 92/100
# 3440/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.8456e-05
# Epoch 92: val_loss did not improve from 0.00014
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - loss: 9.8464e-05 - val_loss: 1.5044e-04
# Epoch 93/100
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.9159e-05
# Epoch 93: val_loss did not improve from 0.00014
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - loss: 9.9159e-05 - val_loss: 1.5459e-04
# Epoch 94/100
# 3445/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0140e-04
# Epoch 94: val_loss did not improve from 0.00014
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - loss: 1.0140e-04 - val_loss: 1.5666e-04
# Epoch 95/100
# 3443/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0334e-04
# Epoch 95: val_loss did not improve from 0.00014
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - loss: 1.0333e-04 - val_loss: 1.4835e-04
# Epoch 96/100
# 3446/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0273e-04
# Epoch 96: val_loss did not improve from 0.00014
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 1.0273e-04 - val_loss: 1.5186e-04
# Epoch 97/100
# 3440/3450 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.8779e-05
# Epoch 97: val_loss did not improve from 0.00014
# 3450/3450 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - loss: 9.8779e-05 - val_loss: 1.4558e-04
# Epoch 97: early stopping

# %% [markdown]
# **Models Evaluation**

# %%
# plot history
plt.plot(history.history['loss'],'r-o', label='train')
plt.plot(history.history['val_loss'],'b-o', label='val')
plt.legend()
plt.title("Attention MSE" , weight='bold')
plt.show()

# %%
# make a prediction
yhat_train = model.predict(X_train)
# Out:
# 3834/3834 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step

# %%
import sklearn.metrics as skm
from math import sqrt

def model_metrics(target: pd.DataFrame, predictions: []) -> None:
    print("Explained variance regression score: %.3f" %skm.explained_variance_score(target, predictions))
    print("Maximum residual error: %.3f" %skm.max_error(target, predictions))
    print("Mean squared error: %.3f" %skm.mean_squared_error(target, predictions))
    print("R2 Score: %.3f" %skm.r2_score(target, predictions))
    print("Root-mean-square Error: %.3f" %sqrt(skm.mean_squared_error(target, predictions)))
    print("Median_absolute_error: %.3f" %skm.median_absolute_error(target , predictions))
    print("Mean_absolute_error: %.3f" %skm.mean_absolute_error(target , predictions))

# %%
# Test Set 
yhat = model.predict(X_test)
# Out:
# 709/709 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step

# %%
print("***  Attention Evaluation ***** ")
model_metrics(y_test , yhat)
# Out:
# ***  Attention Evaluation *****
# Explained variance regression score: 0.992
# Maximum residual error: 0.209
# Mean squared error: 0.000
# R2 Score: 0.991
# Root-mean-square Error: 0.012
# Median_absolute_error: 0.004
# Mean_absolute_error: 0.007

# %%
plt.figure(figsize=(15,6))
plt.plot( y_test[:1000], marker='.', label="actual")
plt.plot( yhat[:1000], 'r', label="prediction")

plt.tight_layout()
sns.despine(top=True)
plt.subplots_adjust(left=0.07)
plt.ylabel('PJME_MW', size=15 , weight='bold')
plt.xlabel('Time step', size=15 , weight='bold')
plt.legend(fontsize=15)
plt.title("Attention PJME_MW Prediction" , weight='bold')
plt.show();
